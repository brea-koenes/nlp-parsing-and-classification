# %% [markdown]
# # CKY Parsing
#
# ## By Brea Koenes

# %% [markdown]
# ### Overview
#
# Building a simple parser that is trained from the ATIS (Air Traffic Information System) portion of the Penn Treebank. The training data consists of short queries and commands spoken by users of a fake robot travel agent.
# The files provided and their purpose are listed below:
#
#     - `train.trees.pre.unk` contains the trees of the training data: binary branching trees with all words that only appear once replaced with `<unk>`
#     - `dev.strings` contains the Strings of the development data
#
# ## CKY Parsing
#
# CKY Parsing, named after its inventors, John Cocke, Daniel Younger, and Tadao Kasami, is a widely used algorithm for parsing sentences in context-free grammars. It stands out for its efficiency and capability to handle ambiguous grammatical structures, making it a fundamental tool in NLP.
#
# ## Importance in NLP
#
# Syntactic parsing, the process of analyzing a sentence's structure according to the rules of a formal grammar, plays a critical role in understanding language. The CKY algorithm, with its bottom-up parsing approach, allows us to decompose complex sentences into their constituent parts, facilitating tasks like machine translation, sentiment analysis, and information extraction.

# %% [markdown]
# ## 01 - Setup
#
# Set up our environment for the CKY Parsing exercise. This includes importing necessary libraries and preparing the environment for parsing.

# %%
import nltk
from nltk.tree import Tree
from nltk.parse import ViterbiParser
import svgling
import math

# %% [markdown]
# ## 02 - Importing and Visualizing the Syntax Tree
#
# ### Syntax Tree
#
# A syntax tree, also known as a parse tree, is a tree representation of the syntactic structure of a sentence. In linguistics and NLP, these trees are crucial for understanding how different parts of a sentence relate to each other according to the rules of grammar.
#
# ### Importance of Syntax Trees in NLP
#
# Syntax trees play a vital role in various NLP applications. They help in:
#
# - **Understanding Sentence Structure:** By breaking down a sentence into its constituent parts, syntax trees make it easier to analyze the grammatical structure.
# - **Improving Language Models:** They are essential in developing more accurate models for tasks like machine translation, speech recognition, and sentiment analysis.
# - **Information Extraction:** Syntax trees aid in extracting meaningful information from complex sentences, which is crucial in tasks like question answering and text summarization.
#
# ### Task: Importing and Visualizing the Syntax Tree
#
# Import a syntax tree from the provided file `train.trees.pre.unk` and visualize its structure.
#
# 1. **Read the First Line of the File:** Use Python's built-in `open` function to access the file. Read the first line of the file, which contains a sentence's syntax tree in a specific format.
#
# 2. **Parse the Syntax Tree:** With the line read from the file, parse it to create a syntax tree. Store this object.
#
# 3. **Print the partial Syntax Tree:** Print it using the `pretty_print` method from the `first_tree` object.

# %%
# Open file and read first line
with open('train.trees.pre.unk', 'r') as file:
    first_line = file.readline().strip()

# Parse syntax tree
first_tree = Tree.fromstring(first_line)

# Print tree
first_tree.pretty_print()
# Out:
#                                         TOP
#                  ________________________|_______________________________________________________
#                S_VP                                                                              |
#   ______________|________________________                                                        |
#  |                                       NP                                                      |
#  |         ______________________________|_________                                              |
#  |        |                                       NP*                                            |
#  |        |                 _______________________|_______                                      |
#  |        |                |                              NP*                                    |
#  |        |                |                  _____________|___________                          |
#  |        |                |                 |                        SBAR                       |
#  |        |                |                 |              ___________|____                     |
#  |        |                |                 |             |               S_VP                  |
#  |        |                |                 |             |       _________|____                |
#  |        NP               PP                PP            |      |              PP              |
#  |     ___|_____       ____|______        ___|_____        |      |          ____|_______        |
#  VB   DT       NNS    IN        NP_NNP   TO      NP_NNP WHNP_WDT VBP        IN         NP_NNP   PUNC
#  |    |         |     |           |      |         |       |      |         |            |       |
# List the     flights from     Baltimore  to     Seattle   that   stop       in      Minneapolis  .

# %% [markdown]
# ## 03 - Convert Trees to Chomsky Normal Form (CNF) and Extract Productions
#
# Transform our syntax trees into Chomsky Normal Form (CNF) and then extract grammatical productions from these CNF trees. This process is crucial for creating a grammar that can be used for parsing.
#
# ### Chomsky Normal Form
#
# Chomsky Normal Form is a way of rewriting and simplifying the grammar of a language. A grammar in CNF has its production rules restricted to a certain standard form. Specifically, each rule must be either:
# - A -> BC, where 'A', 'B', and 'C' are non-terminal symbols, and 'B' and 'C' are not the start symbol.
# - A -> a, where 'A' is a non-terminal symbol and 'a' is a terminal symbol.
# This form is particularly useful for parsing algorithms and simplifying the analysis of grammatical structures.
#
# ### Task: Convert Trees to Chomsky Normal Form (CNF) and Extract Productions
#
# 1. **Read Syntax Trees from File:**
#    Read all the syntax trees from the provided file `train.trees.pre.unk` into a list.
#
# 2. **Convert Trees to CNF:**
#     Convert each tree into Chomsky Normal Form.
#
# 3. **Extract Productions:**
#
#    Having converted the trees to Chomsky Normal Form, our next step is to extract the grammatical productions from these CNF trees. Grammatical productions are essentially the rules that define how sentences in a language can be constructed and are pivotal for understanding the structure and syntax of the language.
#
#    To accomplish this, create a list named `productions`. This list will store all the production rules extracted from each tree. Traverse through each of the CNF trees, and for every tree, use the `productions()` method. This method will break down the tree into its constituent production rules. Accumulate these rules in the `productions` list, which will later be used for constructing our grammar.

# %%
import nltk
from nltk import Tree

trees = []
with open('train.trees.pre.unk', 'r') as file:
    for line in file:
        # Read each line, strip whitespace, parse into tree object
        tree = Tree.fromstring(line.strip())
        trees.append(tree)

# Convert each tree to Chomsky Normal Form
cnf_trees = []
for tree in trees:
    tree.chomsky_normal_form(horzMarkov=2)
    cnf_trees.append(tree)

# Extract productions from all CNF trees
productions = []
for tree in cnf_trees:
    productions.extend(tree.productions())

# %% [markdown]
# ## 04 - Inducing a Probabilistic Context-Free Grammar (PCFG) from Productions
#
# Induce a Probabilistic Context-Free Grammar (PCFG) from these productions. This step is crucial in the realm of syntactic parsing in NLP.
#
# ### What is a Probabilistic Context-Free Grammar (PCFG)?
#
# A Probabilistic Context-Free Grammar (PCFG) is an extension of the standard context-free grammar that associates probabilities with its production rules. In PCFG, each production rule is assigned a probability that signifies how frequently that rule is used to generate a sentence in a language. This probabilistic aspect allows us to model linguistic phenomena more realistically and handle ambiguities in natural language more effectively.
#
# ### Importance of PCFG in NLP
#
# In NLP, PCFGs are instrumental for several reasons:
# - **Handling Ambiguity:** They help in dealing with ambiguities inherent in natural languages by preferring more likely structures over less likely ones.
# - **Improving Parsing Accuracy:** PCFGs enhance the accuracy of parsing algorithms, making them more effective in understanding complex sentences.
# - **Application in Various NLP Tasks:** They are fundamental in tasks such as machine translation, speech recognition, and syntactic analysis.
#
# ### Steps to Induce a PCFG from Productions:
#
# 1. **Define the Start Symbol:**
#    First, identify the start symbol for grammar. Create a nonterminal symbol using `nltk.Nonterminal` passing the start symbol as paremeter.
#
# 2. **Induce the PCFG:**
#     Utilize the `induce_pcfg` function from NLTK to create a PCFG grammer based on the start symbol and the list of **productions**.
#
# 3. **Display Sample Grammar Rules:**
# To get a sense of what our induced grammar looks like, print out a sample of the grammar rules. Display the **first 10 rules** as an example.

# %%
# Define start symbol for grammar
start_symbol = nltk.Nonterminal('TOP')

# Introduce PCFG using start symbol and list of productions
grammar = nltk.induce_pcfg(start_symbol, productions)

# Display first 10 grammar rules
for i, production in enumerate(grammar.productions()[:10],1):
    print(production)
# Out:
# TOP -> S_VP PUNC [0.208955]
# S_VP -> VB NP [0.122302]
# VB -> 'List' [0.0180723]
# NP -> NP NP* [0.115942]
# NP -> DT NNS [0.0855072]
# DT -> 'the' [0.626263]
# NNS -> 'flights' [0.746411]
# NP* -> PP NP* [0.121076]
# PP -> IN NP_NNP [0.349927]
# IN -> 'from' [0.452282]

# %% [markdown]
# ## 05 - Import Sentences to parse
#
# Create a list named `sentences` with all the sentences from 'dev.strings' file. Each line is a sentence.

# %%
# Create a list of sentences from dev_strings file
sentences = []
with open('dev.strings', 'r') as file:
    for line in file:
        sentences.append(line.strip())

# %% [markdown]
# ## 06 - CKY Parsing with Unknown Word Handling
#
# ### Objective
#
# Create a function named `cky_parsing` that applies the CKY algorithm to parse sentences using a given Probabilistic Context-Free Grammar (PCFG). The function should handle unknown words by substituting them with `<unk>` and should employ the Viterbi parsing algorithm. Additionally, it should account for the grammar's productions to identify known words.
#
# ### Instructions
#
# 1. **Function Definition:**
#    - Name the function `cky_parsing`.
#    - It should accept two parameters: `sentences` (a list of sentences to be parsed) and `grammar` (the PCFG used for parsing).
#
# 2. **Preprocessing:**
#    - Within the function, construct a set of known words present in the given productions (generate 'production' set from the grammar passed). This set is used to determine if words in the sentences are covered by the grammar.
#
# 3. **Viterbi Parser Setup:**
#    - Initialize a Viterbi parser using the provided PCFG.
#
# 4. **Sentence Processing:**
#    - Iterate over each sentence in `sentences`:
#      - Tokenize the sentence.
#      - Replace any word not found in the set of known words with `<unk>`.
#      - Parse the sentence using the Viterbi parser.
#      - Select the parse with the highest probability, or handle cases where no valid parse is found (check the `parse_all` method of the ViterbiParser object from the `nltk.parse` library)
#
#
# ### Return Value
#
# The function should return a list of tuples. One tuple per sentence processed. Each tuple should contain:
#    - The index of the sentence within the input list.
#    - The original sentence.
#    - The best parse tree found, or an appropriate value indicating the grammatical structure of sentences. If there is no best parse found, set the best parse to `None`.

# %%
# Define function
def cky_parsing(sentences, grammar):
    results = []

    # Construct set of known words
    known_words = set()
    for production in grammar.productions():
        for rhs in production.rhs():
            if isinstance(rhs, str):
                known_words.add(rhs)

    # Initialize Viterbi parser with PCFG
    parser = nltk.ViterbiParser(grammar)

    # Iterate over each sentence with its index
    for idx, sentence in enumerate(sentences):
        tokens = sentence.split()

        # Replace unknown words with unk
        modified_tokens = [token if token in known_words else '<unk>' for token in tokens]
        
        # Parse modified sentence
        try:
            parse_trees = list(parser.parse_all(modified_tokens))
            if parse_trees:
                best_parse = parse_trees[0]
            else:
                best_parse = None
        except ValueError:
            best_parse = None

        # Add result tuple to list
        results.append((idx, sentence, best_parse))

    return results

# %% [markdown]
# ## 07 - Executing CKY Parsing Function on Sentences
#
# Execute the following cell to parse and print the parsing results. Do not change the code:

# %%
# Example of using the function (with 'sentences' being the list of sentences)
# Assuming 'productions' are the productions from the induced grammar
cky_charts = cky_parsing(sentences, grammar)

for index, sentence, chart in cky_charts:
    print(f"Line {index}: {sentence}")

    if chart:
        print(f"Probability: {math.log(chart.prob())}")  # Using log probability
        print("Parse:")
        chart.pretty_print()  # Pretty print the parse tree
    else:
        print("No parse available for this sentence")
    print("-------------------------------------------------")
# Out:
# Line 0: The flight should be eleven a.m tomorrow .
# No parse available for this sentence
# -------------------------------------------------
# Line 1: I would like it to have a stop in New York and I would like a flight that serves breakfast .
# Probability: -85.26919694246591
# Parse:
#                                                            TOP
#                _____________________________________________|______________________________________________________________________
#               S                                                                                                                    |
#    ___________|_______________                                                                                                     |
#   |                           VP                                                                                                   |
#   |       ____________________|_____________________________                                                                       |
#   |      |                                                  VP                                                                     |
#   |      |     _____________________________________________|____                                                                  |
#   |      |    |                                                  S                                                                 |
#   |      |    |            ______________________________________|____                                                             |
#   |      |    |           |                                           S*                                                           |
#   |      |    |           |                                       ____|______                                                      |
#   |      |    |           S                                      |           S                                                     |
#   |      |    |      _____|___                                   |     ______|____                                                 |
#   |      |    |     |         VP                                 |    |           VP                                               |
#   |      |    |     |      ___|____________                      |    |       ____|_____________                                   |
#   |      |    |     |     |                VP                    |    |      |                  VP                                 |
#   |      |    |     |     |    ____________|____                 |    |      |     _____________|_______                           |
#   |      |    |     |     |   |                 NP               |    |      |    |                     NP                         |
#   |      |    |     |     |   |         ________|___             |    |      |    |         ____________|_______                   |
#   |      |    |     |     |   |        |            PP           |    |      |    |        |                   SBAR                |
#   |      |    |     |     |   |        |         ___|___         |    |      |    |        |             _______|_____             |
#   |      |    |     |     |   |        NP       |       NP       |    |      |    |        NP           |            S_VP          |
#   |      |    |     |     |   |     ___|___     |    ___|___     |    |      |    |     ___|____        |        _____|______      |
# NP_PRP   MD   VB  NP_PRP  TO VBP   DT      NN   IN NNP     NNP   CC NP_PRP   MD   VB   DT       NN   WHNP_WDT  VBZ        ADVP_RB PUNC
#   |      |    |     |     |   |    |       |    |   |       |    |    |      |    |    |        |       |       |            |     |
#   I    would like   it    to have  a      stop  in New     York and   I    would like  a      flight   that   serves       <unk>   .
#
# -------------------------------------------------
# Line 2: Which of these serve dinner ?
# Probability: -20.205461711126294
# Parse:
#                          TOP
#                      _____|_________________
#                   SBARQ                     |
#            _________|___________            |
#          WHNP                   |           |
#     ______|____                 |           |
#    |           PP             SQ_VP         |
#    |       ____|____       _____|_____      |
# WHNP_WDT  IN      NP_DT  VBP        NP_NN  PUNC
#    |      |         |     |           |     |
#  Which    of      these serve       dinner  ?
#
# -------------------------------------------------
# Line 3: Which ones stop in Nashville ?
# Probability: -23.54035303502083
# Parse:
#                        TOP
#                    _____|__________________
#                 SBARQ                      |
#         __________|_____                   |
#        |              SQ_VP                |
#        |           _____|____              |
#       WHNP        |          PP            |
#    ____|____      |      ____|______       |
#  WDT       NNS   VBP    IN        NP_NNP  PUNC
#   |         |     |     |           |      |
# Which      ones  stop   in      Nashville  ?
#
# -------------------------------------------------
# Line 4: Are there any flights arriving after eleven a.m ?
# Probability: -37.278934919588785
# Parse:
#                                  TOP
#           ________________________|_______________________________
#          SQ                                                       |
#    ______|______                                                  |
#   |            SQ*                                                |
#   |       ______|_________________                                |
#   |      |                       SQ*                              |
#   |      |           _____________|____________                   |
#   |      |          |                          VP                 |
#   |      |          |              ____________|____              |
#   |      |          |             |                 PP            |
#   |      |          |             |        _________|_____        |
#   |      |          NP            |       |               NP      |
#   |      |       ___|_____        |       |          _____|___    |
#  VBP  NP_NP_EX  DT       NNS     VBG      IN        CD        RB PUNC
#   |      |      |         |       |       |         |         |   |
# <unk>  there   any     flights arriving after     eleven     a.m  ?
#
# -------------------------------------------------
# Line 5: What flights do you have from Ontario ?
# Probability: -27.165608415597145
# Parse:
#                                   TOP
#                               _____|_________________________
#                            SBARQ                             |
#           ___________________|_____                          |
#          |                         SQ                        |
#          |               __________|____                     |
#          |              |              SQ*                   |
#          |              |     __________|___                 |
#          |              |    |              VP               |
#          |              |    |      ________|____            |
#      WHNP_WHNP          |    |     |             PP          |
#   _______|________      |    |     |         ____|_____      |
# WDT              NNS   VBP NP_PRP VBP       IN       NP_NNP PUNC
#  |                |     |    |     |        |          |     |
# What           flights  do  you   have     from     Ontario  ?
#
# -------------------------------------------------
# Line 6: Where does this flight stop ?
# Probability: -23.118034506633716
# Parse:
#                             TOP
#                     _________|___________
#                  SBARQ                   |
#      ______________|____                 |
#     |                   SQ               |
#     |         __________|____            |
#     |        |              SQ*          |
#     |        |           ____|______     |
#     |        |          NP          |    |
#     |        |      ____|____       |    |
# WHADVP_WRB  VBP    DT        NN   VP_VB PUNC
#     |        |     |         |      |    |
#   <unk>    <unk>  this     flight  stop  ?
#
# -------------------------------------------------
# Line 7: What type of aircraft is Alaska 's flight two eighty two ?
# Probability: -65.5019663330801
# Parse:
#                                           TOP
#                                 ___________|_________________________________________
#                              SBARQ                                                   |
#                  ______________|___________                                          |
#                 |                          SQ                                        |
#                 |                      ____|_____________                            |
#                 |                     |                  NP                          |
#                 |                     |          ________|_________                  |
#                 |                     |         |                 NP*                |
#                 |                     |         |         _________|____             |
#                WHNP                   |         |        |             NP*           |
#        _________|________             |         |        |      ________|____        |
#      WHNP                PP           |         NP       |     |            NP*      |
#   ____|____           ___|_____       |     ____|___     |     |         ____|___    |
# WDT        NN        IN      NP_NN   VBZ  NNP      POS   NN    CD       CD       CD PUNC
#  |         |         |         |      |    |        |    |     |        |        |   |
# What      type       of     aircraft  is <unk>      's flight two     <unk>     two  ?
#
# -------------------------------------------------
# Line 8: Does the other American flight ?
# Probability: -27.792843774184718
# Parse:
#                      TOP
#             __________|_________________
#            SQ                           |
#   _________|____                        |
#  |              NP                      |
#  |     _________|_____                  |
#  |    |              NP*                |
#  |    |     __________|______           |
#  |    |    |                NP*         |
#  |    |    |           ______|____      |
# VBZ   DT   JJ        NNP          NN   PUNC
#  |    |    |          |           |     |
# Does the other     American     flight  ?
#
# -------------------------------------------------
# Line 9: I 'd like to fly from Tampa to Montreal .
# Probability: -31.73457837559068
# Parse:
#                     TOP
#          ____________|________________________________________
#         S                                                     |
#    _____|___                                                  |
#   |         VP                                                |
#   |      ___|____                                             |
#   |     |        VP                                           |
#   |     |    ____|_______                                     |
#   |     |   |           S_VP                                  |
#   |     |   |     _______|_________                           |
#   |     |   |    |                 VP                         |
#   |     |   |    |    _____________|_____                     |
#   |     |   |    |   |                  VP*                   |
#   |     |   |    |   |         __________|_______             |
#   |     |   |    |   |        PP                 PP           |
#   |     |   |    |   |    ____|____           ___|_____       |
# NP_PRP  MD  VB   TO  VB  IN      NP_NNP      TO      NP_NNP  PUNC
#   |     |   |    |   |   |         |         |         |      |
#   I     'd like  to fly from     Tampa       to     Montreal  .
#
# -------------------------------------------------
# Line 10: On Tuesday I 'd like to fly from Detroit to Saint Petersburg .
# Probability: -53.976364043753456
# Parse:
#                                     TOP
#             _________________________|______________________________________________
#            S                                                                        |
#       _____|____________                                                            |
#      |                  S*                                                          |
#      |             _____|___                                                        |
#      |            |         VP                                                      |
#      |            |      ___|____                                                   |
#      |            |     |        VP                                                 |
#      |            |     |    ____|___                                               |
#      |            |     |   |       S_VP                                            |
#      |            |     |   |     ___|_______________                               |
#      |            |     |   |    |                   VP                             |
#      |            |     |   |    |    _______________|_____                         |
#      |            |     |   |    |   |                    VP*                       |
#      |            |     |   |    |   |          ___________|____                    |
#      |            |     |   |    |   |         |                PP                  |
#      |            |     |   |    |   |         |            ____|____               |
#      PP           |     |   |    |   |         PP          |         NP             |
#   ___|_____       |     |   |    |   |     ____|_____      |     ____|______        |
#  IN      NP_NNP NP_PRP  MD  VB   TO  VB   IN       NP_NNP  TO  NNP         NNP     PUNC
#  |         |      |     |   |    |   |    |          |     |    |           |       |
#  On     Tuesday   I     'd like  to fly  from     Detroit  to Saint     Petersburg  .
#
# -------------------------------------------------
# Line 11: Flight from Long Beach to Columbus on twenty seventh .
# Probability: -42.84490372214105
# Parse:
#                               TOP
#                 _______________|_____________________________________
#             FRAG_NP                                                  |
#    ____________|_______________                                      |
#   |                            PP                                    |
#   |      ______________________|_________                            |
#   |     |                                NP                          |
#   |     |             ___________________|______                     |
#   |     |            |                         NP*                   |
#   |     |            |              ____________|____                |
#   |     |            |             |                 PP              |
#   |     |            |             |             ____|_____          |
#   |     |            NP            PP           |          NP        |
#   |     |       _____|____      ___|_____       |     _____|____     |
# NP_NN   IN    NNP        NNP   TO      NP_NNP   IN   CD         RB  PUNC
#   |     |      |          |    |         |      |    |          |    |
# Flight from   Long      Beach  to     Columbus  on twenty     <unk>  .
#
# -------------------------------------------------
# Line 12: Which ones leave in the morning ?
# Probability: -25.00508109699838
# Parse:
#                       TOP
#                    ____|_________________________
#                 SBARQ                            |
#         __________|_________                     |
#        |                  SQ_VP                  |
#        |           _________|____                |
#        |          |              PP              |
#        |          |     _________|___            |
#       WHNP        |    |             NP          |
#    ____|____      |    |          ___|_____      |
#  WDT       NNS   VBP   IN        DT        NN   PUNC
#   |         |     |    |         |         |     |
# Which      ones leave  in       the     morning  ?
#
# -------------------------------------------------
# Line 13: Which of these flights serve dinner ?
# Probability: -22.333548752061326
# Parse:
#                               TOP
#                      __________|________________________
#                   SBARQ                                 |
#                _____|_______________________            |
#              WHNP                           |           |
#     __________|_____                        |           |
#    |                PP                      |           |
#    |       _________|____                   |           |
#    |      |              NP               SQ_VP         |
#    |      |          ____|_____        _____|_____      |
# WHNP_WDT  IN        DT        NNS    VBP        NP_NN  PUNC
#    |      |         |          |      |           |     |
#  Which    of      these     flights serve       dinner  ?
#
# -------------------------------------------------
# Line 14: Which is last ?
# Probability: -10.795356311716928
# Parse:
#                 TOP
#             _____|____________
#          SBARQ                |
#     _______|_____             |
#    |           SQ_VP          |
#    |        _____|______      |
# WHNP_WDT  VBZ        ADJP_JJ PUNC
#    |       |            |     |
#  Which     is          last   ?
#
# -------------------------------------------------
# Line 15: Show me all the fares from one way fares from Tacoma to Montreal .
# Probability: -51.33429661880188
# Parse:
#                                     TOP
#                   ___________________|__________________________________________________________
#                 S_VP                                                                            |
#   _______________|___________________                                                           |
#  |                                  VP*                                                         |
#  |      _____________________________|_______                                                   |
#  |     |                                     NP                                                 |
#  |     |          ___________________________|________                                          |
#  |     |         |                                   NP*                                        |
#  |     |         |                        ____________|____________________                     |
#  |     |         |                       PP                                |                    |
#  |     |         |               ________|___                              |                    |
#  |     |         NP             |            NP                           NP*                   |
#  |     |      ___|____          |     _______|___                __________|_______             |
#  |     |     |       NP*        |    |          NP*             PP                 PP           |
#  |     |     |    ____|____     |    |        ___|____      ____|____           ___|_____       |
#  VB  NP_PRP PDT  DT       NNS   IN   CD      NN      NNS   IN      NP_NNP      TO      NP_NNP  PUNC
#  |     |     |   |         |    |    |       |        |    |         |         |         |      |
# Show   me   all the      fares from one     way     fares from     Tacoma      to     Montreal  .
#
# -------------------------------------------------
# Line 16: Which flights serve breakfast ?
# Probability: -15.390613975714734
# Parse:
#                           TOP
#                       _____|__________________
#                    SBARQ                      |
#         _____________|___________             |
#       WHNP                     SQ_VP          |
#    ____|______              _____|______      |
#  WDT         NNS          VBP        ADJP_JJ PUNC
#   |           |            |            |     |
# Which      flights       serve        <unk>   ?
#
# -------------------------------------------------
# Line 17: What airline provides only connecting flights between Denver and San Francisco ?
# Probability: -51.14029196886647
# Parse:
#                                            TOP
#                      _______________________|______________________________________________
#                   SBARQ                                                                    |
#        _____________|____________                                                          |
#       |                        SQ_VP                                                       |
#       |              ____________|__________________                                       |
#       |             |                              VP*                                     |
#       |             |      _________________________|__________                            |
#       |             |     |                                    NP                          |
#       |             |     |            ________________________|_____                      |
#       |             |     |           |                             NP*                    |
#       |             |     |           |                    __________|___                  |
#       |             |     |           |                   |             NP*                |
#       |             |     |           |                   |           ___|___              |
#      WHNP           |     |           NP                  PP         |       NP            |
#   ____|______       |     |       ____|_____         _____|____      |    ___|______       |
# WDT          NN    VBP  NP_PRP   JJ        NNS      IN       NP_NNP  CC NNP        NNP    PUNC
#  |           |      |     |      |          |       |          |     |   |          |      |
# What      airline <unk> <unk>  <unk>     flights between     Denver and San     Francisco  ?
#
# -------------------------------------------------
# Line 18: List all flights from Burbank to Denver .
# Probability: -28.31879842076823
# Parse:
#                       TOP
#        ________________|___________________________________
#      S_VP                                                  |
#   ____|________________                                    |
#  |                     NP                                  |
#  |          ___________|________________                   |
#  |         |                           NP*                 |
#  |         |                 ___________|_______           |
#  |         NP               PP                  PP         |
#  |     ____|_____       ____|_____           ___|____      |
#  VB   DT        NNS    IN       NP_NNP      TO     NP_NNP PUNC
#  |    |          |     |          |         |        |     |
# List all      flights from     Burbank      to     Denver  .
#
# -------------------------------------------------
# Line 19: Are there any stopovers for Delta one seven three nine ?
# Probability: -60.24001745240625
# Parse:
#                                           TOP
#           _________________________________|______________________________________
#          SQ                                                                       |
#    ______|_________________                                                       |
#   |                       SQ*                                                     |
#   |       _________________|_______________                                       |
#   |      |                                 NP                                     |
#   |      |                         ________|_____________________________         |
#   |      |                        NP                                     |        |
#   |      |           _____________|______________                        |        |
#   |      |          |                           NP*                      |        |
#   |      |          |                  __________|_______                |        |
#   |      |          NP                PP                NP*             NP*       |
#   |      |       ___|______        ___|____           ___|____       ____|___     |
#  VBP  NP_NP_EX  DT        NNS     IN     NP_NNP      CD       CD    CD       CD  PUNC
#   |      |      |          |      |        |         |        |     |        |    |
# <unk>  there   any     stopovers for     Delta      one     seven three     nine  ?
#
# -------------------------------------------------
# Line 20: What is M I A ?
# No parse available for this sentence
# -------------------------------------------------
# Line 21: What flights leave from Phoenix to anywhere ?
# Probability: -20.042598300271997
# Parse:
#                                     TOP
#                            __________|________________________
#                         SBARQ                                 |
#        ___________________|__________                         |
#       |                            SQ_VP                      |
#       |              ________________|_____                   |
#       |             |                     VP*                 |
#       |             |           ___________|_______           |
#      WHNP           |          PP                  PP         |
#   ____|______       |      ____|_____           ___|____      |
# WDT         NNS    VBP    IN       NP_NNP      TO     NP_NNP PUNC
#  |           |      |     |          |         |        |     |
# What      flights leave  from     Phoenix      to     <unk>   ?
#
# -------------------------------------------------
# Line 22: What flights are there from Houston to Dallas ?
# Probability: -20.41522975378351
# Parse:
#                                     TOP
#                                ______|___________________________________
#                             SBARQ                                        |
#           ____________________|______                                    |
#          |                           SQ                                  |
#          |               ____________|__________                         |
#          |              |                      SQ*                       |
#          |              |      _________________|_____                   |
#          |              |     |                      SQ*                 |
#          |              |     |            ___________|_______           |
#      WHNP_WHNP          |     |           PP                  PP         |
#   _______|________      |     |       ____|_____           ___|____      |
# WDT              NNS   VBP NP_NP_EX  IN       NP_NNP      TO     NP_NNP PUNC
#  |                |     |     |      |          |         |        |     |
# What           flights are  there   from     Houston      to     Dallas  ?
#
# -------------------------------------------------
# Line 23: What flights are there from Memphis to Las Vegas ?
# Probability: -25.397581485676408
# Parse:
#                                     TOP
#                    __________________|__________________________________
#                 SBARQ                                                   |
#           ________|___________                                          |
#          |                    SQ                                        |
#          |               _____|_________________                        |
#          |              |                      SQ*                      |
#          |              |      _________________|_____                  |
#          |              |     |                      SQ*                |
#          |              |     |            ___________|___              |
#          |              |     |           |               PP            |
#          |              |     |           |            ___|___          |
#      WHNP_WHNP          |     |           PP          |       NP        |
#   _______|________      |     |       ____|_____      |    ___|____     |
# WDT              NNS   VBP NP_NP_EX  IN       NP_NNP  TO NNP      NNP  PUNC
#  |                |     |     |      |          |     |   |        |    |
# What           flights are  there   from     Memphis  to Las     Vegas  ?
#
# -------------------------------------------------
# Line 24: Flights from Cleveland to Miami .
# Probability: -14.358259491284384
# Parse:
#                                TOP
#                       __________|______________
#                   FRAG_NP                      |
#     _________________|______                   |
#    |                       NP*                 |
#    |           _____________|_______           |
#    |          PP                    PP         |
#    |      ____|______            ___|____      |
#  NP_NNS  IN        NP_NNP       TO     NP_NNP PUNC
#    |     |           |          |        |     |
# Flights from     Cleveland      to     Miami   .
#
# -------------------------------------------------
# Line 25: Flights on Sunday from Tampa to Charlotte .
# Probability: -24.663094271810696
# Parse:
#                            TOP
#             ________________|_____________________________________
#         FRAG_NP                                                   |
#     _______|________________                                      |
#    |                       NP*                                    |
#    |              __________|_______________                      |
#    |             |                         NP*                    |
#    |             |                __________|_______              |
#    |             PP              PP                 PP            |
#    |        _____|____       ____|____           ___|______       |
#  NP_NNS    IN       NP_NNP  IN      NP_NNP      TO       NP_NNP  PUNC
#    |       |          |     |         |         |          |      |
# Flights    on       Sunday from     Tampa       to     Charlotte  .
#
# -------------------------------------------------
# Line 26: Show me flights that leave in the morning .
# No parse available for this sentence
# -------------------------------------------------
# Line 27: Flights arriving in Las Vegas from Memphis and New York City on Sunday .
# Probability: -59.46067052833196
# Parse:
#                                                         TOP
#                                                     _____|____________________________________
#                                                 FRAG_NP                                       |
#                    ________________________________|_________                                 |
#                   |                                         NP*                               |
#                   |                           _______________|___                             |
#                   NP                         |                  NP*                           |
#     ______________|___                       |            _______|________                    |
#    |                  VP                     |           |                NP                  |
#    |        __________|___                   |           |        ________|________           |
#    |       |              PP                 |           |       NP                |          |
#    |       |       _______|___               |           |    ___|____             |          |
#    |       |      |           NP             PP          |   |       NP*           PP         |
#    |       |      |        ___|____      ____|_____      |   |    ____|___      ___|____      |
#  NP_NNS   VBG     IN     NNP      NNP   IN       NP_NNP  CC NNP NNP      NNP   IN     NP_NNP PUNC
#    |       |      |       |        |    |          |     |   |   |        |    |        |     |
# Flights arriving  in     Las     Vegas from     Memphis and New York     City  on     Sunday  .
#
# -------------------------------------------------
# Line 28: Display flights arriving within thirty minutes of each other .
# Probability: -50.39735832602076
# Parse:
#                                       TOP
#               _________________________|_________________________________
#              S                                                           |
#         _____|_______________                                            |
#        |                     VP                                          |
#        |              _______|_________________                          |
#        |             |                         NP                        |
#        |             |                  _______|__________               |
#        |             |                 NP                 PP             |
#        |             |             ____|_______       ____|____          |
#        NP            |            QP           |     |         NP        |
#    ____|_____        |        ____|____        |     |     ____|____     |
#   JJ        NNS     VBG      RB        CD     NNS    IN   DT        JJ  PUNC
#   |          |       |       |         |       |     |    |         |    |
# <unk>     flights arriving <unk>     thirty minutes  of <unk>     other  .
#
# -------------------------------------------------
# Line 29: Show me the fare .
# Probability: -9.773761130880418
# Parse:
#                  TOP
#               ____|____________
#             S_VP               |
#   ___________|____             |
#  |               VP*           |
#  |      __________|___         |
#  |     |              NP       |
#  |     |           ___|___     |
#  VB  NP_PRP       DT      NN  PUNC
#  |     |          |       |    |
# Show   me        the     fare  .
#
# -------------------------------------------------
# Line 30: What 's the earliest flight from Dallas to Houston ?
# No parse available for this sentence
# -------------------------------------------------
# Line 31: From Toronto to Atlanta in the afternoon .
# Probability: -32.41455499744773
# Parse:
#                                   TOP
#                              ______|______________________
#                            FRAG                           |
#        _____________________|______                       |
#       |                          FRAG*                    |
#       |                ____________|____                  |
#       |               |                 PP                |
#       |               |             ____|___              |
#       PP              PP           |        NP            |
#   ____|_____       ___|_____       |     ___|______       |
#  IN       NP_NNP  TO      NP_NNP   IN   DT         NN    PUNC
#  |          |     |         |      |    |          |      |
# From     Toronto  to     Atlanta   in  the     afternoon  .
#
# -------------------------------------------------
# Line 32: What flights from Kansas City to Denver .
# Probability: -18.938937713375072
# Parse:
#                                       TOP
#                             ___________|___________________
#                        FRAG_WHNP                           |
#        ____________________|___________                    |
#       |                              WHNP*                 |
#       |                     ___________|________           |
#       |                    PP                   |          |
#       |             _______|______              |          |
#      WHNP          |              NP            PP         |
#   ____|______      |        ______|____      ___|____      |
# WDT         NNS    IN     NNP         NNP   TO     NP_NNP PUNC
#  |           |     |       |           |    |        |     |
# What      flights from   Kansas       City  to     Denver  .
#
# -------------------------------------------------
# Line 33: What flights from Washington D C to Toronto .
# Probability: -30.321051417500744
# Parse:
#                                        TOP
#                             ____________|____________________________
#                        FRAG_WHNP                                     |
#        ____________________|____________                             |
#       |                               WHNP*                          |
#       |                             ____|________________            |
#       |                            PP                    |           |
#       |             _______________|____                 |           |
#       |            |                    NP               |           |
#       |            |        ____________|____            |           |
#      WHNP          |       |                 NP          PP          |
#   ____|______      |       |             ____|___     ___|_____      |
# WDT         NNS    IN    NP_NNP        NNP      NNP  TO      NP_NNP PUNC
#  |           |     |       |            |        |   |         |     |
# What      flights from Washington       D        C   to     Toronto  .
#
# -------------------------------------------------
# Line 34: Are any of those on American Airlines ?
# Probability: -36.90550889732547
# Parse:
#                     TOP
#         _____________|______________________________
#       S_VP                                          |
#    ____|_____________                               |
#   |                  NP                             |
#   |     _____________|____                          |
#   |    |                 NP*                        |
#   |    |         _________|_____                    |
#   |    |        |               PP                  |
#   |    |        |          _____|______             |
#   |    |        PP        |            NP           |
#   |    |     ___|____     |      ______|_____       |
#   VB   DT   IN     NP_DT  IN   NNP          NNP    PUNC
#   |    |    |        |    |     |            |      |
# <unk> any   of     those  on American     Airlines  ?
#
# -------------------------------------------------
# Line 35: What flights from Montreal to Las Vegas on Saturday .
# Probability: -28.016594790689915
# Parse:
#                                                TOP
#                                          _______|_______________________________
#                                     FRAG_WHNP                                   |
#        _________________________________|_______                                |
#       |                                       WHNP*                             |
#       |                  _______________________|_________                      |
#       |                 |                               WHNP*                   |
#       |                 |                        _________|________             |
#       |                 |                       PP                 |            |
#       |                 |                _______|____              |            |
#      WHNP               PP              |            NP            PP           |
#   ____|______       ____|_____          |        ____|____      ___|_____       |
# WDT         NNS    IN       NP_NNP      TO     NNP       NNP   IN      NP_NNP  PUNC
#  |           |     |          |         |       |         |    |         |      |
# What      flights from     Montreal     to     Las      Vegas  on     Saturday  .
#
# -------------------------------------------------
# Line 36: What is the price ?
# Probability: -12.342831591372237
# Parse:
#                   TOP
#                ____|_____________
#             SBARQ                |
#     __________|____              |
#    |               SQ            |
#    |      _________|___          |
#    |     |             NP        |
#    |     |          ___|____     |
# WHNP_WP VBZ        DT       NN  PUNC
#    |     |         |        |    |
#   What   is       the     price  ?
#
# -------------------------------------------------
# Line 37: On Thursday .
# Probability: -15.97158949314833
# Parse:
#               TOP
#         _______|______
#     FRAG_PP           |
#   _____|_______       |
#  IN          NP_NNP  PUNC
#  |             |      |
#  On         Thursday  .
#
# -------------------------------------------------
# Line 38: Flights from Cleveland to Kansas City .
# Probability: -19.62582720313387
# Parse:
#                            TOP
#                       ______|___________________
#                   FRAG_NP                       |
#     _________________|______                    |
#    |                       NP*                  |
#    |           _____________|____               |
#    |          |                  PP             |
#    |          |              ____|_____         |
#    |          PP            |          NP       |
#    |      ____|______       |     _____|___     |
#  NP_NNS  IN        NP_NNP   TO  NNP       NNP  PUNC
#    |     |           |      |    |         |    |
# Flights from     Cleveland  to Kansas     City  .
#
# -------------------------------------------------
# Line 39: Price from Cleveland to Kansas City round trip .
# Probability: -33.49940663742464
# Parse:
#                                   TOP
#                              ______|_________________________________
#                          FRAG_NP                                     |
#    _________________________|______                                  |
#   |                               NP*                                |
#   |          ______________________|_________                        |
#   |         |                                PP                      |
#   |         |                ________________|____                   |
#   |         |               |                     NP                 |
#   |         |               |             ________|_________         |
#   |         PP              |            NP                NP*       |
#   |     ____|______         |       _____|___           ____|___     |
# NP_NN  IN        NP_NNP     TO    NNP       NNP        JJ       NN  PUNC
#   |    |           |        |      |         |         |        |    |
# Price from     Cleveland    to   Kansas     City     round     trip  .
#
# -------------------------------------------------
# Line 40: Flights from Ontario to Florida .
# Probability: -16.624476940107556
# Parse:
#                              TOP
#                      _________|______________
#                  FRAG_NP                     |
#     ________________|_____                   |
#    |                     NP*                 |
#    |           ___________|_______           |
#    |          PP                  PP         |
#    |      ____|_____           ___|____      |
#  NP_NNS  IN       NP_NNP      TO     NP_NNP PUNC
#    |     |          |         |        |     |
# Flights from     Ontario      to     <unk>   .
#
# -------------------------------------------------
# Line 41: First class round trip airfare from Indianapolis to Memphis .
# Probability: -42.74625489735171
# Parse:
#                                        TOP
#                                    _____|_________________________________________
#                                FRAG_NP                                            |
#                    _______________|___________________________                    |
#                   NP                                          |                   |
#         __________|____                                       |                   |
#        |              NP*                                    NP*                  |
#        |           ____|____                  ________________|_______            |
#        NP         |        NP*               PP                       PP          |
#    ____|____      |     ____|_____       ____|_______              ___|_____      |
#   JJ        NN    JJ   NN         NN    IN         NP_NNP         TO      NP_NNP PUNC
#   |         |     |    |          |     |            |            |         |     |
# First     class round trip     airfare from     Indianapolis      to     Memphis  .
#
# -------------------------------------------------
# Line 42: Flights from Boston to Pittsburgh .
# Probability: -16.085480439374866
# Parse:
#                              TOP
#                      _________|__________________
#                  FRAG_NP                         |
#     ________________|_____                       |
#    |                     NP*                     |
#    |           ___________|_______               |
#    |          PP                  PP             |
#    |      ____|_____           ___|______        |
#  NP_NNS  IN       NP_NNP      TO       NP_NNP   PUNC
#    |     |          |         |          |       |
# Flights from      Boston      to     Pittsburgh  .
#
# -------------------------------------------------
# Line 43: What 's the cheapest ?
# No parse available for this sentence
# -------------------------------------------------
# Line 44: Restriction code A P slash five seven .
# Probability: -40.51715309572969
# Parse:
#                             TOP
#                        ______|_______________________
#                    FRAG_NP                           |
#         ______________|______                        |
#        |                    NP*                      |
#        |         ____________|____                   |
#        |        |                NP*                 |
#        |        |      ___________|___               |
#        |        |     |              NP*             |
#        |        |     |       ________|____          |
#        NP       |     |      |            NP*        |
#    ____|___     |     |      |         ____|____     |
#   JJ       NN  NNP   SYM     JJ       CD        CD  PUNC
#   |        |    |     |      |        |         |    |
# <unk>     code  A     P    <unk>     five     seven  .
#
# -------------------------------------------------
# Line 45: Flights from New York to Miami .
# Probability: -19.14136739656581
# Parse:
#                          TOP
#                  _________|___________________
#              FRAG_NP                          |
#     ____________|_________                    |
#    |                     NP*                  |
#    |             _________|________           |
#    |            PP                 |          |
#    |      ______|_____             |          |
#    |     |            NP           PP         |
#    |     |       _____|___      ___|____      |
#  NP_NNS  IN    NNP       NNP   TO     NP_NNP PUNC
#    |     |      |         |    |        |     |
# Flights from   New       York  to     Miami   .
#
# -------------------------------------------------
# Line 46: Departing before ten a.m .
# Probability: -22.071032674864018
# Parse:
#                          TOP
#                      _____|___________
#                  FRAG_VP              |
#      _______________|_____            |
#     |                     PP          |
#     |        _____________|___        |
#     |       |                 NP      |
#     |       |              ___|___    |
#    VBG      IN            CD      RB PUNC
#     |       |             |       |   |
# Departing before         ten     a.m  .
#
# -------------------------------------------------
# Line 47: Cheapest fare .
# Probability: -8.663174636220438
# Parse:
#                  TOP
#              _____|____
#          FRAG_NP       |
#     ________|_____     |
#   JJS             NN  PUNC
#    |              |    |
# Cheapest         fare  .
#
# -------------------------------------------------
# Line 48: Departing after six p.m .
# Probability: -20.851792398407294
# Parse:
#                         TOP
#                     _____|___________
#                 FRAG_VP              |
#      ______________|_____            |
#     |                    PP          |
#     |        ____________|___        |
#     |       |                NP      |
#     |       |             ___|___    |
#    VBG      IN           CD      RB PUNC
#     |       |            |       |   |
# Departing after         six     p.m  .
#
# -------------------------------------------------
# Line 49: Departing Wednesday after five o'clock .
# Probability: -27.196720256195114
# Parse:
#                                 TOP
#                         _________|________________
#                     FRAG_VP                       |
#      __________________|_____                     |
#     |                       VP*                   |
#     |          ______________|___                 |
#     |         |                  PP               |
#     |         |         _________|____            |
#     |         |        |              NP          |
#     |         |        |          ____|_____      |
#    VBG      NP_NNP     IN        CD         RB   PUNC
#     |         |        |         |          |     |
# Departing Wednesday  after      five     o'clock  .
#
# -------------------------------------------------
# Line 50: Show me ground transportation in Westchester County .
# Probability: -34.0146820476418
# Parse:
#                             TOP
#         _____________________|____________________________________
#       S_VP                                                        |
#   _____|_____________________                                     |
#  |                          VP*                                   |
#  |      _____________________|_________                           |
#  |     |                               NP                         |
#  |     |             __________________|_______                   |
#  |     |            |                          PP                 |
#  |     |            |                   _______|_______           |
#  |     |            NP                 |               NP         |
#  |     |       _____|________          |        _______|____      |
#  VB  NP_PRP   NN             NN        IN     NNP          NNP   PUNC
#  |     |      |              |         |       |            |     |
# Show   me   ground     transportation  in Westchester     County  .
#
# -------------------------------------------------
# Line 51: Newark to Cleveland .
# Probability: -11.932904129388387
# Parse:
#             TOP
#          ____|_____________
#        FRAG                |
#    _____|____              |
#   |          PP            |
#   |      ____|______       |
# NP_NNP  TO        NP_NNP  PUNC
#   |     |           |      |
# Newark  to      Cleveland  .
#
# -------------------------------------------------
# Line 52: Airline T W A .
# Probability: -26.629620274856467
# Parse:
#                     TOP
#                 _____|___________
#             FRAG_NP              |
#     ___________|_____            |
#    |                NP*          |
#    |      ___________|___        |
#    |     |              NP*      |
#    |     |            ___|___    |
#  NP_NN  NNP         NNP     NNP PUNC
#    |     |           |       |   |
# Airline  T           W       A   .
#
# -------------------------------------------------
# Line 53: Fares .
# No parse available for this sentence
# -------------------------------------------------
# Line 54: Show me the fares .
# Probability: -9.885087289719353
# Parse:
#                  TOP
#               ____|_____________
#             S_VP                |
#   ___________|____              |
#  |               VP*            |
#  |      __________|___          |
#  |     |              NP        |
#  |     |           ___|____     |
#  VB  NP_PRP       DT      NNS  PUNC
#  |     |          |        |    |
# Show   me        the     fares  .
#
# -------------------------------------------------
# Line 55: Show me the fares from Dallas to San Francisco .
# Probability: -28.79951143075871
# Parse:
#                            TOP
#               ______________|_____________________________________
#             S_VP                                                  |
#   ___________|______________                                      |
#  |                         VP*                                    |
#  |      ____________________|_________                            |
#  |     |                              NP                          |
#  |     |           ___________________|_____                      |
#  |     |          |                        NP*                    |
#  |     |          |               __________|___                  |
#  |     |          |              |              PP                |
#  |     |          |              |           ___|___              |
#  |     |          NP             PP         |       NP            |
#  |     |      ____|____      ____|____      |    ___|______       |
#  VB  NP_PRP  DT       NNS   IN      NP_NNP  TO NNP        NNP    PUNC
#  |     |     |         |    |         |     |   |          |      |
# Show   me   the      fares from     Dallas  to San     Francisco  .
#
# -------------------------------------------------
# Line 56: Show me the flights from San Diego to San Francisco on Southwest Airlines .
# Probability: -46.11462609149707
# Parse:
#                                           TOP
#                         ___________________|_____________________________________________________
#                       S_VP                                                                       |
#   _____________________|___________________                                                      |
#  |                                        VP*                                                    |
#  |      ___________________________________|____                                                 |
#  |     |                                        NP                                               |
#  |     |          ______________________________|___                                             |
#  |     |         |                                 NP*                                           |
#  |     |         |                 _________________|__________                                  |
#  |     |         |                |                           NP*                                |
#  |     |         |                |                  __________|_____________                    |
#  |     |         |                PP                PP                       PP                  |
#  |     |         |            ____|___           ___|___               ______|______             |
#  |     |         NP          |        NP        |       NP            |             NP           |
#  |     |      ___|_____      |     ___|____     |    ___|______       |       ______|_____       |
#  VB  NP_PRP  DT       NNS    IN  NNP      NNP   TO NNP        NNP     IN    NNP          NNP    PUNC
#  |     |     |         |     |    |        |    |   |          |      |      |            |      |
# Show   me   the     flights from San     Diego  to San     Francisco  on Southwest     Airlines  .
#
# -------------------------------------------------
# Line 57: Show me the restrictions .
# Probability: -9.945611387807077
# Parse:
#                  TOP
#               ____|_____________
#             S_VP                |
#   ___________|____              |
#  |               VP*            |
#  |      __________|___          |
#  |     |              NP        |
#  |     |           ___|____     |
#  VB  NP_PRP       DT       NN  PUNC
#  |     |          |        |    |
# Show   me        the     <unk>  .
#
# -------------------------------------------------

# %% [markdown]
# ### 08 - Export Grammar

# %%
# Importing dill library for model serialization
import dill

# Serialization with dill
with open('grammar.dill', 'wb') as file:
    dill.dump(grammar , file)
